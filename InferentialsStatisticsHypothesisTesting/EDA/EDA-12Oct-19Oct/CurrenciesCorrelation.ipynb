# %% [markdown]
# ### Taken this data set from the International Monetary Fund website.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('currencies.csv')
df.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula  ...  South African Rand  Sri Lanka Rupee  Swedish Krona  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Currency                    11 non-null     object
#  1   Chinese Yuan                11 non-null     float64
#  2   Euro                        11 non-null     float64
#  3   Japanese Yen                10 non-null     float64
#  4   U.K. Pound Sterling         11 non-null     float64
#  5   U.S. Dollar                 11 non-null     float64
#  6   Algerian Dinar              9 non-null      float64
#  7   Australian Dollar           11 non-null     float64
#  8   Bahrain Dinar               11 non-null     float64
#  9   Botswana Pula               9 non-null      float64
#  10  Brazilian Real              11 non-null     float64
#  11  Brunei Dollar               10 non-null     float64
#  12  Canadian Dollar             10 non-null     float64
# ...

# %%
df.corr()
# Out:
#                             Chinese Yuan      Euro  Japanese Yen  \
# Chinese Yuan                    1.000000  0.151596      0.117566
# Euro                            0.151596  1.000000     -0.645719
# Japanese Yen                    0.117566 -0.645719      1.000000
# U.K. Pound Sterling             0.108695  0.531150     -0.970308
# U.S. Dollar                     0.291582 -0.210587      0.210295
# Algerian Dinar                  0.815216  0.259964     -0.388099
# Australian Dollar               0.077983  0.331588     -0.582032
# Bahrain Dinar                   0.291926 -0.209926      0.209957
# Botswana Pula                   0.467693  0.469668     -0.627015
# Brazilian Real                  0.320508  0.383645     -0.641122
# Brunei Dollar                   0.499400  0.103766     -0.260258
# Canadian Dollar                -0.186643  0.638422     -0.662233
# Chilean Peso                    0.028821  0.242743     -0.809751
# ...

# %%
fd2=df[['Chinese Yuan','Euro', 'Japanese Yen', 'U.K. Pound Sterling','U.S. Dollar','Australian Dollar','Indian Rupee']].copy()

# %%
alpha = ['Euro', 'Japanese Yen', 'U.K. Pound Sterling','U.S. Dollar','Australian Dollar','Indian Rupee']
plt.matshow(fd2.corr())
plt.show()

# %%
fd2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Euro                 11 non-null     float64
#  1   Japanese Yen         10 non-null     float64
#  2   U.K. Pound Sterling  11 non-null     float64
#  3   U.S. Dollar          11 non-null     float64
#  4   Australian Dollar    11 non-null     float64
#  5   Indian Rupee         9 non-null      float64
# dtypes: float64(6)
# memory usage: 656.0 bytes

# %%
fd2.head()
# Out:
#       Euro  Japanese Yen  U.K. Pound Sterling  U.S. Dollar  Australian Dollar  \
# 0  1.25367       143.645              1.05054      1.39596            1.87126
# 1  1.25322       142.715              1.06143      1.39684            1.85825
# 2  1.25834       140.540              1.07300      1.39286            1.87313
# 3  1.25737       140.640              1.06911      1.39316            1.85236
# 4  1.25797       140.510              1.07261      1.39257            1.85974
#
#    Indian Rupee
# 0       94.1451
# 1       94.1513
# 2           NaN
# 3       94.0345
# 4       93.9408

# %%
fd2.corr()
# Out:
#                          Euro  Japanese Yen  U.K. Pound Sterling  U.S. Dollar  \
# Euro                 1.000000     -0.645719             0.531150    -0.210587
# Japanese Yen        -0.645719      1.000000            -0.970308     0.210295
# U.K. Pound Sterling  0.531150     -0.970308             1.000000    -0.042303
# U.S. Dollar         -0.210587      0.210295            -0.042303     1.000000
# Australian Dollar    0.331588     -0.582032             0.579213     0.607010
# Indian Rupee         0.243851     -0.270123             0.314681     0.872862
#
#                      Australian Dollar  Indian Rupee
# Euro                          0.331588      0.243851
# Japanese Yen                 -0.582032     -0.270123
# U.K. Pound Sterling           0.579213      0.314681
# U.S. Dollar                   0.607010      0.872862
# Australian Dollar             1.000000      0.921475
# Indian Rupee                  0.921475      1.000000

# %%
import numpy as np
alphabets = ['Euro', 'Japanese Yen', 'U.K. Pound Sterling','U.S. Dollar','Australian Dollar','Indian Rupee']
  
figure = plt.figure(figsize=[7,5]) 
axes = figure.add_subplot(111) 
caxes = axes.matshow(fd2) 
figure.colorbar(caxes) 
  
axes.set_xticklabels(['']+alphabets) 
axes.set_yticklabels(['']+alphabets) 
  
plt.show()

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(fd2.corr(), fignum=f.number)
plt.xticks(range(fd2.shape[1]), fd2.columns, fontsize=14, rotation=45)
plt.yticks(range(fd2.shape[1]), fd2.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
