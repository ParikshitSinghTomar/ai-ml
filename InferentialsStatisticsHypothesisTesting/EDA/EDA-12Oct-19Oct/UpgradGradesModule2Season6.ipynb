# %% [markdown]
# ### PGDML > Module 2 > Session 6

# %% [markdown]
# The typical dates and times when UpGrad students submit their assignments

# %%
import pandas as pd

# %%
df=pd.read_csv('grades.csv')
df.head()
# Out:
#                                           submission        submit_time
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49

# %%
df['submit_time'] = pd.to_datetime(df['submit_time'])

# %%
df.head()
# Out:
#                                           submission         submit_time
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44... 2017-01-03 20:28:52
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c... 2017-01-03 20:18:21
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43... 2017-01-03 22:37:08
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49... 2017-01-02 21:43:19
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f... 2017-01-03 15:27:49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   submission   198 non-null    object
#  1   submit_time  198 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 3.2+ KB

# %%
df['hour']=df['submit_time'].dt.hour
df['minute']=df['submit_time'].dt.minute
df['second']=df['submit_time'].dt.second
df['day']=df['submit_time'].dt.day
df['month']=df['submit_time'].dt.month
df['year']=df['submit_time'].dt.year

# %%
df.head()
# Out:
#                                           submission         submit_time  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44... 2017-01-03 20:28:52
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c... 2017-01-03 20:18:21
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43... 2017-01-03 22:37:08
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49... 2017-01-02 21:43:19
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f... 2017-01-03 15:27:49
#
#    hour  minute  second  day  month  year
# 0    20      28      52    3      1  2017
# 1    20      18      21    3      1  2017
# 2    22      37       8    3      1  2017
# 3    21      43      19    2      1  2017
# 4    15      27      49    3      1  2017

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   submission   198 non-null    object
#  1   submit_time  198 non-null    datetime64[ns]
#  2   hour         198 non-null    int64
#  3   minute       198 non-null    int64
#  4   second       198 non-null    int64
#  5   day          198 non-null    int64
#  6   month        198 non-null    int64
#  7   year         198 non-null    int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 12.5+ KB

# %%
df.head()
# Out:
#                                           submission         submit_time  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44... 2017-01-03 20:28:52
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c... 2017-01-03 20:18:21
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43... 2017-01-03 22:37:08
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49... 2017-01-02 21:43:19
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f... 2017-01-03 15:27:49
#
#    hour  minute  second  day  month  year
# 0    20      28      52    3      1  2017
# 1    20      18      21    3      1  2017
# 2    22      37       8    3      1  2017
# 3    21      43      19    2      1  2017
# 4    15      27      49    3      1  2017

# %%
# count of zip formats
df['file_format']=df['submission'].apply(lambda x: x.rsplit('.', 1)[1])

# %%
df.head()
# Out:
#                                           submission         submit_time  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44... 2017-01-03 20:28:52
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4c... 2017-01-03 20:18:21
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-43... 2017-01-03 22:37:08
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-49... 2017-01-02 21:43:19
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f... 2017-01-03 15:27:49
#
#    hour  minute  second  day  month  year file_format
# 0    20      28      52    3      1  2017         zip
# 1    20      18      21    3      1  2017         zip
# 2    22      37       8    3      1  2017         zip
# 3    21      43      19    2      1  2017         zip
# 4    15      27      49    3      1  2017         zip

# %%
df['file_format'].value_counts()
# Out:
# zip    189
# R        7
# 7z       2
# Name: file_format, dtype: int64

# %%
189/(189+7+2)
# Out:
# 0.9545454545454546

# %%
#create a new column where deadline one crossed True/False and second column deadline 2 crossed True/False
def deadline1Check(day,month,year):
    if year>2017:
        return true
    elif month>1:
        return true
    elif day>3:
        return true
df['deadline1']=((df['year']==2017)&(df['month']==1)&(df['day']>3))
df['deadline2']=((df['year']==2017)&(df['month']>=1)&(df['day']>9))

# %%
df.head(30)
# Out:
#                                            submission         submit_time  \
# 0   https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44... 2017-01-03 20:28:52
# 1   https://ckd.upgrad.com/UpGrad/185242ff-7508-4c... 2017-01-03 20:18:21
# 2   https://ckd.upgrad.com/UpGrad/a353d129-c100-43... 2017-01-03 22:37:08
# 3   https://ckd.upgrad.com/UpGrad/002fc912-faa1-49... 2017-01-02 21:43:19
# 4   https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f... 2017-01-03 15:27:49
# 5   https://ckd.upgrad.com/UpGrad/0ab308ab-2b3a-4c... 2017-01-04 02:43:46
# 6   https://ckd.upgrad.com/UpGrad/ba2c249c-dac8-46... 2017-01-03 23:41:25
# 7   https://ckd.upgrad.com/UpGrad/d8969806-6760-44... 2017-01-09 23:49:09
# 8   https://ckd.upgrad.com/UpGrad/5ff1d0ab-816b-48... 2016-12-30 14:14:17
# 9   https://ckd.upgrad.com/UpGrad/0d507851-d102-47... 2017-01-03 21:18:04
# 10  https://ckd.upgrad.com/UpGrad/9a756d83-7a83-49... 2017-01-03 23:55:41
# 11  https://ckd.upgrad.com/UpGrad/873211b9-5a3q-45... 2017-01-09 23:41:23
# ...

# %%
df['deadline1'].value_counts()
# Out:
# False    155
# True      43
# Name: deadline1, dtype: int64

# %%
df['deadline2'].value_counts()
# Out:
# False    194
# True       4
# Name: deadline2, dtype: int64

# %%
df.groupby(df['year'])['month'].value_counts()
# Out:
# year  month
# 2016  12        13
#       11         1
# 2017  1        183
#       2          1
# Name: month, dtype: int64

# %%
#df.to_csv('updated_grades.csv')

# %%
df['date']=df['submit_time'].dt.day df['submit_time'].dt.month df['submit_time'].dt.year
# Out:
# 3     121
# 9      21
# 2      14
# 4      12
# 30      6
# 1       6
# 10      3
# 8       3
# 29      2
# 28      2
# 19      2
# 7       2
# 31      1
# 21      1
# 17      1
# 6       1
# Name: day, dtype: int64

# %%
df['hour'].value_counts()
# Out:
# 23    66
# 21    27
# 22    24
# 20    16
# 0     10
# 1      8
# 18     6
# 14     6
# 13     6
# 17     4
# 15     4
# 3      3
# 10     3
# 12     3
# 4      2
# 19     2
# 2      2
# 16     2
# 11     1
# 9      1
# 8      1
# 6      1
# Name: hour, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(df['hour'])
plt.show()
