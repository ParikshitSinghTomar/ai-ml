# %% [markdown]
# ### Tendulkar Batting - Univariate Analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('tendulkar_ODI.csv')
df.head(20)
# Out:
#    Runs Mins   BF 4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0     0    -    2  0  0       0   5    caught    2      v Pakistan
# 1     0    2    2  0  0       0   5    caught    2   v New Zealand
# 2    36   51   39  5  0    92.3   6    caught    1   v New Zealand
# 3    19   38   35  1  1   54.28   4    bowled    2       v England
# 4    31   31   26  3  0  119.23   6    bowled    2       v England
# 5    36    -   22  3  2  163.63   5    bowled    1     v Sri Lanka
# 6    53    -   41  7  1  129.26   5    bowled    2     v Sri Lanka
# 7    30    -   29  1  2  103.44   5    caught    1     v Sri Lanka
# 8   DNB    -    -  -  -       -   -         -    2    v Bangladesh
# 9     4    -   11  0  0   36.36   5       lbw    2     v Sri Lanka
# 10   53    -   70  2  0   75.71   4       lbw    2     v Sri Lanka
# 11   62    -   73  8  1   84.93   4    caught    2  v South Africa
# 12    4    -    8  0  0      50   4    caught    1  v South Africa
# ...

# %%
df.shape
# Out:
# (295, 12)

# %%
# Drop rows which column unnamed which is used to show numbering which we already have in panda dataframe
df=df[df.Runs!='DNB']
df.head(20)
# Out:
#    Runs Mins   BF 4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0     0    -    2  0  0       0   5    caught    2      v Pakistan
# 1     0    2    2  0  0       0   5    caught    2   v New Zealand
# 2    36   51   39  5  0    92.3   6    caught    1   v New Zealand
# 3    19   38   35  1  1   54.28   4    bowled    2       v England
# 4    31   31   26  3  0  119.23   6    bowled    2       v England
# 5    36    -   22  3  2  163.63   5    bowled    1     v Sri Lanka
# 6    53    -   41  7  1  129.26   5    bowled    2     v Sri Lanka
# 7    30    -   29  1  2  103.44   5    caught    1     v Sri Lanka
# 9     4    -   11  0  0   36.36   5       lbw    2     v Sri Lanka
# 10   53    -   70  2  0   75.71   4       lbw    2     v Sri Lanka
# 11   62    -   73  8  1   84.93   4    caught    2  v South Africa
# 12    4    -    8  0  0      50   4    caught    1  v South Africa
# 13    1    -    3  0  0   33.33   4    caught    1  v South Africa
# ...

# %%
df.shape
# Out:
# (293, 12)

# %%
df=df[df.Runs!='-']
df.shape
# Out:
# (293, 12)

# %%
df.Runs=df.Runs.apply(lambda x: x.replace('*',''))

# %%
df.head(10)
# Out:
#    Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition      Ground  \
# 0     0    -   2  0  0       0   5    caught    2     v Pakistan  Gujranwala
# 1     0    2   2  0  0       0   5    caught    2  v New Zealand     Dunedin
# 2    36   51  39  5  0    92.3   6    caught    1  v New Zealand  Wellington
# 3    19   38  35  1  1   54.28   4    bowled    2      v England       Leeds
# 4    31   31  26  3  0  119.23   6    bowled    2      v England  Nottingham
# 5    36    -  22  3  2  163.63   5    bowled    1    v Sri Lanka      Nagpur
# 6    53    -  41  7  1  129.26   5    bowled    2    v Sri Lanka        Pune
# 7    30    -  29  1  2  103.44   5    caught    1    v Sri Lanka      Margao
# 9     4    -  11  0  0   36.36   5       lbw    2    v Sri Lanka     Cuttack
# 10   53    -  70  2  0   75.71   4       lbw    2    v Sri Lanka     Kolkata
#
#    Start Date
# 0   18-Dec-89
# 1    1-Mar-90
# 2    6-Mar-90
# 3   18-Jul-90
# 4   20-Jul-90
# 5    1-Dec-90
# ...

# %%
df.Runs.sum()
# Out:
# '...'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 293 entries, 0 to 294
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        293 non-null    object
#  1   Mins        293 non-null    object
#  2   BF          293 non-null    object
#  3   4s          293 non-null    object
#  4   6s          293 non-null    object
#  5   SR          293 non-null    object
#  6   Pos         293 non-null    object
#  7   Dismissal   293 non-null    object
#  8   Inns        293 non-null    object
#  9   Opposition  293 non-null    object
#  10  Ground      293 non-null    object
#  11  Start Date  293 non-null    object
# dtypes: object(12)
# memory usage: 29.8+ KB

# %%
df.Runs.value_counts()
# Out:
# 1      16
# 2      14
# 0      12
# 4       9
# 21      8
#        ..
# 141     1
# 110     1
# 72      1
# 105     1
# 102     1
# Name: Runs, Length: 106, dtype: int64

# %%
df=df[df.Runs!='TDNB']

# %%
df.Runs=df.Runs.astype('int32')

# %%
df.Runs.sum()
# Out:
# 11519

# %%
df.shape
# Out:
# (292, 12)

# %%
df.head(20)
# Out:
#     Runs Mins   BF 4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0      0    -    2  0  0       0   5    caught    2      v Pakistan
# 1      0    2    2  0  0       0   5    caught    2   v New Zealand
# 2     36   51   39  5  0    92.3   6    caught    1   v New Zealand
# 3     19   38   35  1  1   54.28   4    bowled    2       v England
# 4     31   31   26  3  0  119.23   6    bowled    2       v England
# 5     36    -   22  3  2  163.63   5    bowled    1     v Sri Lanka
# 6     53    -   41  7  1  129.26   5    bowled    2     v Sri Lanka
# 7     30    -   29  1  2  103.44   5    caught    1     v Sri Lanka
# 9      4    -   11  0  0   36.36   5       lbw    2     v Sri Lanka
# 10    53    -   70  2  0   75.71   4       lbw    2     v Sri Lanka
# 11    62    -   73  8  1   84.93   4    caught    2  v South Africa
# 12     4    -    8  0  0      50   4    caught    1  v South Africa
# 13     1    -    3  0  0   33.33   4    caught    1  v South Africa
# ...

# %%
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('tendulkar_ODI.csv')
plt.hist(df.Runs, bins=20)
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(df['4s'])
plt.show()

# %%
df['4s'].value_counts()
# Out:
# 0     69
# 1     37
# 2     29
# 3     25
# 4     17
# 5     16
# 9     15
# 6     14
# 8     13
# 7     13
# 10    11
# 13     8
# 12     5
# 16     4
# 15     4
# 11     4
# 14     3
# 19     2
# 20     1
# 17     1
# 25     1
# Name: 4s, dtype: int64

# %%
scores=pd.DataFrame([['0-10',],], columns = ['Percentage', 'counts'])
